# %% [markdown]
# # Python Basics Assignment No: 25

# %% [markdown]
# Q. What's the difference between lists enclosed by square brackets and parentheses in Python?

# %% [markdown]
# A: The difference between list enclosed by square brakets and paratheses in Python is that the list in the square bracket are mutable, whereas the listin parentheses are immutable and called as tuples.

# %% [markdown]
# Q.What is the relationship between generators and iterators?

# %% [markdown]
# A. Iterators are the objects that use the next() method to get the next value of the sequence. A generator is a function that produces or yields a sequence of values using a yield statement. Classes are used to Implement the iterators. Functions are used to implement the generator

# %%
from IPython.display import Image, display
display(Image(filename='/home/jovyan/work/Comp_It_Gen.png'))
#Source: https://www.codingninjas.com/studio/library/iterators-and-generators-in-python#:~:text=Iterators%20are%20the%20objects%20that,used%20to%20implement%20the%20generator.

# %% [markdown]
# Q.What are the signs that a function is a generator function?

# %% [markdown]
# A. A function with yield statements is a generator function
# A generator function is a function with one or more yield statements in it.
#
# Unlike regular functions, generator functions return generator objects. Meaning, when you call a generator function, it doesn't run the function. Instead, it gives you back a generator object.
#
# If you loop over that generator object, it will run the function until a yield statement is reached. At that point the generator object will put itself on pause, and yield the next item. This process will continue over and over until you've consumed all the items within the generator.

# %%
from IPython.display import Image, display
display(Image(filename='/home/jovyan/work/Yield.png'))
#Source: https://www.pythonmorsels.com/what-is-a-generator-function/#:~:text=A%20function%20with%20yield%20statements,doesn't%20run%20the%20function.

# %% [markdown]
# Q.What is the purpose of a yield statement?

# %% [markdown]
# A. The yield keyword in Python is similar to a return statement used for returning values in Python which returns a generator object to the one who calls the function which contains yield, instead of simply returning a value. The main difference between them is, the return statement terminates the execution of the function. Whereas, the yield statement only pauses the execution of the function. Another difference is return statements are never executed. whereas, yield statements are executed when the function resumes its execution.
#
#  In layman terms, the yield keyword will turn any expression that is given with it into a generator object and return it to the caller.

# %% [markdown]
# Q. What is the relationship between map calls and list comprehensions? Make a comparison and
# contrast between the two.

# %% [markdown]
# A. List comprehension is more concise and easier to read as compared to map.
# - List comprehension are used when a list of results is required as map only returns a map object and does not return any list.
# - Map is faster in case of calling an already defined function (as no lambda is required).
# - List comprehension allows filtering. In map, we have no such facility. For example, to print all even numbers in range of 100, we can write [n for n in range(100) if n%2 == 0]. There is no alternate for it in map
# - List comprehension is faster than map when we need to evaluate expressions that are too long or complicated to express

# %%
#Source from https://towardsdatascience.com/comparing-list-comprehensions-vs-built-in-functions-in-python-which-is-better-1e2c9646fafe
from IPython.display import Image, display
display(Image(filename='/home/jovyan/work/List_comprehension.png'))

# %%
#Source from https://towardsdatascience.com/comparing-list-comprehensions-vs-built-in-functions-in-python-which-is-better-1e2c9646fafe
from IPython.display import Image, display
display(Image(filename='/home/jovyan/work/map_fun.png'))

# %%
#The code to demonstrate the speed among list and the map
lst = list(range(1000000))

# %%
# list comprehension
# %timeit -r 10 -n 10 [i / 0.939276 for i in lst]
# Out:
# 120 ms ± 4.65 ms per loop (mean ± std. dev. of 10 runs, 10 loops each)

# %%
# predefined conversion function
def eur_to_usd(x):
    return x / 0.939276
# map with predefined input function

# %%
# %timeit -r 10 -n 10 list(map(eur_to_usd, lst))

# %%
# map with lambda function
# %timeit -r 10 -n 10 list(map(lambda x: x / 0.939276, lst))
# Out:
# 183 ms ± 2.5 ms per loop (mean ± std. dev. of 10 runs, 10 loops each)
